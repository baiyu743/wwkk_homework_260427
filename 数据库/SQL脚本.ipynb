-- %% [markdown]
-- # [student_project]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [student_project]    Script Date: 2026/4/22 11:18:34 ******/
CREATE DATABASE [student_project]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'student_project', FILENAME = N'D:\SOLServer\MSSQL16.MSSQLSERVER\MSSQL\DATA\student_project.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'student_project_log', FILENAME = N'D:\SOLServer\MSSQL16.MSSQLSERVER\MSSQL\DATA\student_project_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [student_project] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [student_project].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [student_project] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [student_project] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [student_project] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [student_project] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [student_project] SET ARITHABORT OFF 
GO
ALTER DATABASE [student_project] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [student_project] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [student_project] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [student_project] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [student_project] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [student_project] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [student_project] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [student_project] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [student_project] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [student_project] SET  DISABLE_BROKER 
GO
ALTER DATABASE [student_project] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [student_project] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [student_project] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [student_project] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [student_project] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [student_project] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [student_project] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [student_project] SET RECOVERY FULL 
GO
ALTER DATABASE [student_project] SET  MULTI_USER 
GO
ALTER DATABASE [student_project] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [student_project] SET DB_CHAINING OFF 
GO
ALTER DATABASE [student_project] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [student_project] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [student_project] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [student_project] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'student_project', N'ON'
GO
ALTER DATABASE [student_project] SET QUERY_STORE = ON
GO
ALTER DATABASE [student_project] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[PAwardsAndDisciplinaryActions]

-- %%
USE [student_project]
GO

-- %%
/****** Object:  Table [dbo].[PAwardsAndDisciplinaryActions]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PAwardsAndDisciplinaryActions](
	[RecordID] [int] IDENTITY(1,1) NOT NULL,
	[StudentID] [varchar](10) NULL,
	[Type] [nvarchar](20) NULL,
	[Description] [nvarchar](max) NULL,
	[Date] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[RecordID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PCourses]

-- %%
/****** Object:  Table [dbo].[PCourses]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PCourses](
	[CourseID] [varchar](10) NOT NULL,
	[CourseName] [nvarchar](100) NULL,
	[InstructorID] [nvarchar](50) NULL,
	[Credits] [int] NULL,
	[SemesterOffered] [nvarchar](20) NULL,
	[CourseCategory] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[CourseID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PGrades]

-- %%
/****** Object:  Table [dbo].[PGrades]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PGrades](
	[GradeID] [int] IDENTITY(1,1) NOT NULL,
	[StudentID] [varchar](10) NULL,
	[CourseID] [varchar](10) NULL,
	[Semester] [nvarchar](20) NULL,
	[Grade] [decimal](5, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[GradeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRolePermissions]

-- %%
/****** Object:  Table [dbo].[PRolePermissions]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRolePermissions](
	[PermissionID] [int] IDENTITY(1,1) NOT NULL,
	[Role] [nvarchar](20) NULL,
	[PermissionType] [nvarchar](50) NULL,
	[TableName] [nvarchar](50) NULL,
	[Operation] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[PermissionID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PStudents]

-- %%
/****** Object:  Table [dbo].[PStudents]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PStudents](
	[StudentID] [varchar](10) NOT NULL,
	[Name] [nvarchar](50) NULL,
	[Gender] [char](1) NULL,
	[DateOfBirth] [date] NULL,
	[Ethnicity] [nvarchar](20) NULL,
	[IDNumber] [varchar](20) NULL,
	[PhoneNumber] [varchar](20) NULL,
	[Email] [nvarchar](100) NULL,
	[Address] [nvarchar](200) NULL,
	[EnrollmentYear] [int] NULL,
	[Class] [nvarchar](20) NULL,
	[Major] [nvarchar](50) NULL,
	[StudyDuration] [int] NULL,
	[EnrollmentStatus] [nvarchar](20) NULL,
	[TuitionStatus] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[StudentID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PUsers]

-- %%
/****** Object:  Table [dbo].[PUsers]    Script Date: 2026/4/22 11:18:35 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PUsers](
	[UserID] [int] IDENTITY(1,1) NOT NULL,
	[Username] [nvarchar](50) NULL,
	[Password] [nvarchar](100) NULL,
	[UserRole] [nvarchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__PAwardsAn__Stude__3F466844]

-- %%
ALTER TABLE [dbo].[PAwardsAndDisciplinaryActions]  WITH CHECK ADD FOREIGN KEY([StudentID])
REFERENCES [dbo].[PStudents] ([StudentID])
GO

-- %% [markdown]
-- # [FK__PGrades__CourseI__3C69FB99]

-- %%
ALTER TABLE [dbo].[PGrades]  WITH CHECK ADD FOREIGN KEY([CourseID])
REFERENCES [dbo].[PCourses] ([CourseID])
GO

-- %% [markdown]
-- # [FK__PGrades__Student__3B75D760]

-- %%
ALTER TABLE [dbo].[PGrades]  WITH CHECK ADD FOREIGN KEY([StudentID])
REFERENCES [dbo].[PStudents] ([StudentID])
GO

-- %% [markdown]
-- # [student_project]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [student_project] SET  READ_WRITE 
GO
